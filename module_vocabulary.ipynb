# %% [markdown]
# # Vocab Testing Ipynb ----

# %% [markdown]
# # File Review

# %%
from os import path
fname = path.expanduser('/Users/Irene/_projects/PycharmProjects/vocab_lib/thirdlong_list.csv')

# %%
# !ls -lh "$fname"
# Out:
# -rw-r--r--@ 1 Irene  staff    21K Nov 17 16:03 /Users/Irene/_projects/PycharmProjects/vocab_lib/thirdlong_list.csv

# %%
path.getsize(fname)
# Out:
# 21709

# %%
path.getsize(fname) / (1<<10)
# Out:
# 21.2001953125

# %%
with open(fname) as fp:
    for lnum, line in enumerate(fp):
        if lnum > 10:
            break
        print(line[:-1])
# Out:
# the,17184
# of,12864
# or,6080
# in,5696
# and,5344
# to,3840
# is,2208
# an,2112
# which,2016
# from,1920
# on,1824

# %% [markdown]
# # Importing Packages

# %%
import codecs
import re
import copy
import collections
import vocabulary

import matplotlib
import numpy as np
import pandas as pd
import nltk

from nltk.stem import PorterStemmer
from nltk.tokenize import WordPunctTokenizer
from __future__ import division
from nltk.corpus import wordnet as wd
from vocabulary.vocabulary import Vocabulary as vb

# %%
df = pd.read_csv(fname, header=None)

# %% [markdown]
# # Gauging the File Further

# %%
df.head()
# Out:
#    the  17184
# 0   of  12864
# 1   or   6080
# 2   in   5696
# 3  and   5344
# 4   to   3840

# %%
len(df)
# Out:
# 2008

# %%
df.columns
# Out:
# Int64Index([0, 1], dtype='int64')

# %%
df.tail()
# Out:
#                0   1
# 2003    thinking  32
# 2004    religion  32
# 2005      belief  32
# 2006  technology  32
# 2007      melayu  32

# %%
df.shape
# Out:
# (2008, 2)

# %%
df.iloc[701:800]
# Out:
#             the  17184
# 701     filling     64
# 702   referring     64
# 703     engaged     64
# 704        rear     64
# 705  equivalent     64
# 706    scoinson     64
# 707   revolving     64
# 708        room     64
# 709     screens     64
# 710    sequence     64
# 711    voussoir     64
# 712    commonly     64
# 713      chords     64
# 714        wing     64
# 715        look     64
# 716   cambridge     64
# 717      online     64
# 718      deurer     64
# 719     related     64
# 720       april     64
# 721        find     64
# 722      masses     64
# 723     hyphens     64
# 724    november     64
# 725        menu     64
# 726      logged     64
# 727  accountlog     64
# 728  namespaces     64
# 729     article     64
# 730        talk     64
# ..          ...    ...
# 770   hullwhite     64
# 771        chen     64
# 772      fisher     64
# 773    equation     64
# 774    crowding     64
# 775      annual     64
# 776    coverage     64
# 777        gold     64
# ...

# %%
df.iloc[301:400]
# Out:
#             the  17184
# 301  especially    128
# 302    buttress    128
# 303      figure    128
# 304      placed    128
# 305     temples    128
# 306     classic    128
# 307         had    128
# 308      orders    128
# 309     systems    128
# 310      shafts    128
# 311    parallel    128
# 312     concave    128
# 313    springer    128
# 314        most    128
# 315        have    128
# 316        area    128
# 317    entrance    128
# 318   connected    128
# 319  triangular    128
# 320        base    128
# 321      timber    128
# 322       using    128
# 323       built    128
# 324        trim    128
# 325        bear    128
# 326       basis    128
# 327  university    128
# 328        arts    128
# 329       james    128
# 330  navigation    128
# ..          ...    ...
# 370       early     96
# 371    handrail     96
# 372    capacity     96
# 373     imposed     96
# 374     without     96
# 375      barrel     96
# 376      lights     96
# 377        only     96
# ...

# %% [markdown]
# # Dictionary module

# %%
vb.synonym("car")
# Out:
# '[{"seq": 0, "text": "motor"}, {"seq": 1, "text": "automotive"}, {"seq": 2, "text": "cart"}]'

# %%
vb.usage_example("car", format='dict')
# Out:
# {0: '"Dude! Where\'s my car?"',
#  1: 'Girl: "oh, you have a nice car"Guy: "oh, you noticed, I\'m flattered..."',
#  2: 'that [car] was going 120 miles per hour vroom bitchh vrooom',
#  3: "Thats the 10th girl I've slammed in my car!",
#  4: 'Bob: you get any a** lately?Mike: F**k yeah, ever since I got a job and a new car the b**tches are lining up.B**tch: Hey nice car!Mike: Back of the line Ho wait your turn.',
#  5: 'When a motorist is within fifty yards of the goal, one shouts "car" and the goal is removed until the car passes. There\'s no need to shout \'"game on" as they do in Canada, where attention spans differ.',
#  6: '"which part of the car is this... the break or the clutch?"',
#  7: 'Bob: Hey Bill, did you see Cars last night?Bill: Yeah it kicked butt',
#  8: 'I drove my car to the fuel station to fill reservoir with liquified prehistoric reptiles.',
#  9: 'My car is enormous.'}

# %%
vb.part_of_speech("car", format='dict')
# Out:
# {0: {'example': 'An automobile.', 'text': 'noun'},
#  1: {'example': 'A vehicle, such as a streetcar, that runs on rails:  a railroad car. ',
#   'text': 'noun'},
#  2: {'example': 'A boxlike enclosure for passengers and freight on a conveyance:  an elevator car. ',
#   'text': 'noun'},
#  3: {'example': 'The part of a balloon or airship that carries people and cargo.',
#   'text': 'noun'},
#  4: {'example': 'Archaic   A chariot, carriage, or cart.', 'text': 'noun'}}

# %%
vb.meaning("car", format='dict')
# Out:
# {0: 'An unpowered unit in a railroad train.',
#  1: 'A sliding fitting that runs along a track.',
#  2: 'an individual vehicle, powered or unpowered, in a multiple unit.',
#  3: 'a conveyance for passengers or freight on a cable railway; &quot;they took a cable car to the top of the mountain&quot;',
#  4: 'The aggregate of desirable characteristics of a car.',
#  5: '(sailing) A sliding fitting that runs along a track.',
#  6: '(rail transport, chiefly North America) An unpowered unit in a railroad train.',
#  7: '(dated) A wheeled vehicle, drawn by a horse or other animal',
#  8: 'automobile, a vehicle steered by a driver',
#  9: '( <i>rail transport</i>) A passenger-carrying unit in a subway or elevated train, whether powered or not.',
#  10: 'A four-wheeled motor vehicle used for land transport, usually propelled by a gasoline or diesel internal combustion engine.',
# ...

# %% [markdown]
# # Create the looping script

# %% [markdown]
# # Test the iteration

# %%
rows = open("/Users/Irene/_projects/PycharmProjects/vocab_lib/output.csv")

for row in rows:
    print(row[0])
    
vb.meaning("car", format='dict')
synsets = wn.synsets('cake')

for word in words:
    print("Lexical Type:", vb.part_of_speech)
    print("Definition:", vb.meaning)
    print ("Example:", synset.examples)
# Out:
#   File "<ipython-input-50-ead059550847>", line 4
#     print(row[])
#               ^
# SyntaxError: invalid syntax

# %% [markdown]
# # Append data to file

# %% [markdown]
# https://stackoverflow.com/questions/42879408/writing-variables-to-a-csv-row-python

# %%
f = open('/Users/Irene/_projects/PycharmProjects/vocab_lib/output.csv','w')
f.append('hi there\n') #Give your csv text here.
## Python will convert \n to os.linesep
f.close()

# %%
#write to csv line by line 
#https://stackoverflow.com/questions/37289951/python-write-to-csv-line-by-line
